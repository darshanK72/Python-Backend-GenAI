# %% [markdown]
# # Recap — Pandas and Data Analysis
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[16-pandas-series.ipynb](16-pandas-series.ipynb)** — Series creation, index, attributes
# - **[17-pandas-dataframe.ipynb](17-pandas-dataframe.ipynb)** — DataFrame, columns, head, info
# - **[20-dataframe-slicing.ipynb](20-dataframe-slicing.ipynb)** — `.loc`, `.iloc`, filtering
# - **[21-treating-missing-values.ipynb](21-treating-missing-values.ipynb)** — `isna`, `fillna`, `dropna`
# - **[34-time-series-data.ipynb](34-time-series-data.ipynb)** — Dates, `to_datetime`, extracting parts
# - **[36-data-cleaning.ipynb](36-data-cleaning.ipynb)** — Cleaning pipeline
# - **[37-grouping-and-aggregation.ipynb](37-grouping-and-aggregation.ipynb)** — `groupby`, `agg`

# %% [markdown]
# **Recap questions**
# 1. Series vs DataFrame?
# 2. `.loc` vs `.iloc`?
# 3. How to fill missing values with column median?

# %% [markdown]
# ## Code cheat sheet

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.head()
df.isna().sum()
df.groupby("category")["sales"].mean()

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
