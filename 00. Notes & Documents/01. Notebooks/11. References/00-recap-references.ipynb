# %% [markdown]
# # Recap — References (Quick Lookup)
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[78-database-fundamentals-reference.ipynb](78-database-fundamentals-reference.ipynb)** — SQL concepts, DB types, normalization
# - **[80-popular-tools-and-python-packages-reference.ipynb](80-popular-tools-and-python-packages-reference.ipynb)** — NumPy, Pandas, sklearn, etc.

# %% [markdown]
# Use these as **lookup sheets** — skim before interviews or when starting a new stack.

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
