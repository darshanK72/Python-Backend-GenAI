# %% [markdown]
# # Recap — Strings and Datetime
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[31-string-operations-i.ipynb](31-string-operations-i.ipynb)** — Indexing, slicing strings
# - **[32-string-operations-ii.ipynb](32-string-operations-ii.ipynb)** — format(), placeholders
# - **[33-string-operations-iii.ipynb](33-string-operations-iii.ipynb)** — Advanced string ops
# - **[35-the-datetime-module.ipynb](35-the-datetime-module.ipynb)** — `datetime`, `strftime`, `strptime`

# %% [markdown]
# **Recap questions**
# 1. f-string vs `.format()`?
# 2. Parse `"2024-06-02"` to datetime?
# 3. Slice `"Python"[0:3]`?

# %% [markdown]
# ## Code cheat sheet

# %%
from datetime import datetime
s = f"Today: {datetime.now():%Y-%m-%d}"
dt = datetime.strptime("2024-01-15", "%Y-%m-%d")

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
