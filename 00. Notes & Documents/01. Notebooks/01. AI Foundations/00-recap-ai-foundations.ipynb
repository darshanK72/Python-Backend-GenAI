# %% [markdown]
# # Recap — AI Foundations
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[01-evolution-of-ai-and-types.ipynb](01-evolution-of-ai-and-types.ipynb)** — Evolution of AI; ANI vs AGI vs ASI; narrow vs general intelligence
# - **[02-ai-applications-across-industries.ipynb](02-ai-applications-across-industries.ipynb)** — AI in healthcare, finance, retail, IoT, education

# %% [markdown]
# **Recap questions**
# 1. Define AI in one sentence.
# 2. Name three types of AI by capability.
# 3. Give two examples of AI you use daily without noticing.

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
