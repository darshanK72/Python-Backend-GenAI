# %% [markdown]
# # Recap — Data Structures
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[07-python-lists-i.ipynb](07-python-lists-i.ipynb)** — Create, index, slice lists
# - **[08-python-lists-ii.ipynb](08-python-lists-ii.ipynb)** — `count`, `index`, list methods
# - **[09-python-lists-iii.ipynb](09-python-lists-iii.ipynb)** — More list operations
# - **[10-nested-python-lists.ipynb](10-nested-python-lists.ipynb)** — 2D lists, nested access
# - **[11-list-comprehension.ipynb](11-list-comprehension.ipynb)** — List comprehensions [x for x in ...]
# - **[26-python-dictionary-i.ipynb](26-python-dictionary-i.ipynb)** — Dict keys/values, access
# - **[27-python-dictionary-ii.ipynb](27-python-dictionary-ii.ipynb)** — Dict methods, iteration
# - **[28-python-dictionary-iii.ipynb](28-python-dictionary-iii.ipynb)** — Advanced dict usage
# - **[30-python-tuples-ii.ipynb](30-python-tuples-ii.ipynb)** — Tuple concat, unpack, `enumerate`, `zip`

# %% [markdown]
# **Recap questions**
# 1. List vs tuple — mutability?
# 2. Write a list comprehension for squares 1–5.
# 3. How do you get all keys from a dict?

# %% [markdown]
# ## Code cheat sheet

# %%
# Quick reference
nums = [1, 2, 3]
nums.append(4)
d = {"a": 1, "b": 2}
squares = [x**2 for x in range(5)]
t = (1, 2, 3)
a, b, c = t

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
