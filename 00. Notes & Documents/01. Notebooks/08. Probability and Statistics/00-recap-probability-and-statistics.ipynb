# %% [markdown]
# # Recap — Probability and Statistics
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[42-discrete-probability.ipynb](42-discrete-probability.ipynb)** — Probability, binomial distribution
# - **[40-correlation.ipynb](40-correlation.ipynb)** — Correlation, coefficient, causation vs correlation
# - **[54-ordinary-least-squares.ipynb](54-ordinary-least-squares.ipynb)** — Linear regression, OLS

# %% [markdown]
# **Recap questions**
# 1. Correlation vs causation?
# 2. What does r close to -1 mean?
# 3. Purpose of OLS?

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
