# %% [markdown]
# # Recap — Python Fundamentals
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[03-python-introduction.ipynb](03-python-introduction.ipynb)** — Colab, notebooks, `print`, basic I/O
# - **[04-variables-and-data-types.ipynb](04-variables-and-data-types.ipynb)** — int, float, str, bool; casting
# - **[05-mind-reader-game-loops-and-conditionals.ipynb](05-mind-reader-game-loops-and-conditionals.ipynb)** — `while`, `if`/`elif`/`else`, mind reader game
# - **[06-python-functions.ipynb](06-python-functions.ipynb)** — `def`, parameters, return, scope

# %% [markdown]
# **Recap questions**
# 1. Difference between `=` and `==`?
# 2. When use `while` vs `for`?
# 3. Write a function that returns the max of two numbers.

# %% [markdown]
# ## Code cheat sheet

# %%
# Quick reference
name = "Darshan"
age = 25
if age >= 18:
    print("Adult")
for i in range(3):
    print(i)
def greet(name):
    return f"Hello, {name}"

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
