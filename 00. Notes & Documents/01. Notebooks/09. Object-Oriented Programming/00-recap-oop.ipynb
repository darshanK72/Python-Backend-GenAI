# %% [markdown]
# # Recap — Object-Oriented Programming
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[45-oop-classes-and-objects.ipynb](45-oop-classes-and-objects.ipynb)** — Classes, `__init__`, methods, objects
# - **[47-oop-encapsulation-i.ipynb](47-oop-encapsulation-i.ipynb)** — Encapsulation, private attributes

# %% [markdown]
# **Recap questions**
# 1. Class vs instance?
# 2. Purpose of `self`?
# 3. What is encapsulation?

# %% [markdown]
# ## Code cheat sheet

# %%
class Person:
    def __init__(self, name):
        self.name = name
    def greet(self):
        return f"Hi, {self.name}"

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
