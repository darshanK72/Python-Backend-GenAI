# %% [markdown]
# # Recap — Graphs and Algorithms
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[68-graphs-and-dijkstras-algorithm.ipynb](68-graphs-and-dijkstras-algorithm.ipynb)** — Graph representation, Dijkstra shortest path
# - **[77-graph-algorithms-reference.ipynb](77-graph-algorithms-reference.ipynb)** — BFS, DFS, reference algorithms

# %% [markdown]
# **Recap questions**
# 1. Directed vs undirected graph?
# 2. When use Dijkstra?
# 3. BFS vs DFS — one use case each?

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
