# %% [markdown]
# # Recap — NumPy and Algorithms
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[12-numpy-arrays-i.ipynb](12-numpy-arrays-i.ipynb)** — ndarray, shape, indexing
# - **[13-claude-shannon-algorithm-i.ipynb](13-claude-shannon-algorithm-i.ipynb)** — Entropy, information theory intro
# - **[14-claude-shannon-algorithm-ii.ipynb](14-claude-shannon-algorithm-ii.ipynb)** — Shannon algorithm applications
# - **[15-numpy-arrays-ii.ipynb](15-numpy-arrays-ii.ipynb)** — Vectorized ops, broadcasting

# %% [markdown]
# **Recap questions**
# 1. Why NumPy vs Python lists for numeric data?
# 2. What is entropy in one line?
# 3. Shape of `np.zeros((3,4))`?

# %% [markdown]
# ## Code cheat sheet

# %%
import numpy as np
arr = np.array([1, 2, 3])
print(arr.shape, arr.mean())

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
