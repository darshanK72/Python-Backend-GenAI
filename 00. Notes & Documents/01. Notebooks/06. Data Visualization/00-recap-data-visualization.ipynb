# %% [markdown]
# # Recap — Data Visualization
#
# Open this notebook for a **fast review** before projects or interviews.
#
# ---
#
# ## Lessons in this module
#
# - **[18-exoplanets-scatter-and-line-plots.ipynb](18-exoplanets-scatter-and-line-plots.ipynb)** — Scatter, line plots (matplotlib)
# - **[19-box-plots.ipynb](19-box-plots.ipynb)** — Box plots, quartiles
# - **[22-folium-maps.ipynb](22-folium-maps.ipynb)** — Interactive maps
# - **[23-meteorite-landings-count-plots.ipynb](23-meteorite-landings-count-plots.ipynb)** — Seaborn count plots
# - **[24-histograms.ipynb](24-histograms.ipynb)** — Histograms, distributions
# - **[25-annotated-bar-graphs.ipynb](25-annotated-bar-graphs.ipynb)** — Bar charts with annotations
# - **[39-bar-plots.ipynb](39-bar-plots.ipynb)** — Bar plots in depth
# - **[41-pie-charts-and-bell-curve.ipynb](41-pie-charts-and-bell-curve.ipynb)** — Pie charts, normal distribution

# %% [markdown]
# **Recap questions**
# 1. When use histogram vs bar chart?
# 2. What does a box plot show?
# 3. Name two seaborn vs matplotlib differences.

# %% [markdown]
# ## Code cheat sheet

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(x, y)
sns.countplot(data=df, x="year")

# %% [markdown]
# ---
#
# **Next:** Open the next module's `00-recap` or return to [`00-complete-syllabus.ipynb`](../00-complete-syllabus.ipynb).
