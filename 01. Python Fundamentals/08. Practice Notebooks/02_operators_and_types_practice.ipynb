# %% [markdown]
# # Practice: Operators & Types
#
# Write your solutions in the **YOUR CODE** cells, then run **Validate** cells.

# %%
# Run this cell once per notebook — provides test validation helpers.

def check_equal(name, actual, expected):
    """Compare actual vs expected; print pass/fail."""
    if actual == expected:
        print(f"✓ {name}")
        return True
    print(f"✗ {name}")
    print(f"  Expected: {expected!r}")
    print(f"  Got:      {actual!r}")
    return False


def run_tests(cases):
    """Run a list of (name, callable) tuples. Callable should return the answer."""
    passed = 0
    for name, fn in cases:
        try:
            if check_equal(name, fn(), True):
                passed += 1
        except Exception as exc:
            print(f"✗ {name} — Error: {type(exc).__name__}: {exc}")
    total = len(cases)
    print(f"\nResult: {passed}/{total} passed")
    if passed == total:
        print("🎉 All tests passed!")
    return passed == total

# %% [markdown]
# ---
#
# ## Problem 1: Sum and product `Easy`
#
# Given `a = 12` and `b = 5`, set `total` to their sum and `product` to their product.
#
# **Examples**
#
# ```
# total → 17, product → 60
# ```

# %%
a, b = 12, 5

# YOUR CODE
total , product = a + b, a * b

# %%
check_equal('total', total, 17)
check_equal('product', product, 60)
# Out:
# ✓ total
# ✓ product
# True

# %% [markdown]
# ---
#
# ## Problem 2: Floor division and remainder `Easy`
#
# For `n = 17` and `d = 5`, compute `quotient` with `//` and `remainder` with `%`.
#
# **Examples**
#
# ```
# quotient → 3, remainder → 2
# ```

# %%
n, d = 17, 5

# YOUR CODE
quotient, remainder = n // d, n % d

# %%
check_equal('quotient', quotient, 3)
check_equal('remainder', remainder, 2)
# Out:
# ✓ quotient
# ✓ remainder
# True

# %% [markdown]
# ---
#
# ## Problem 3: Power `Easy`
#
# Set `result` to `2` raised to the power `10` using `**`.
#
# **Examples**
#
# ```
# result → 1024
# ```

# %%
# YOUR CODE
result = 2**10

# %%
check_equal('result', result, 1024)
# Out:
# ✓ result
# True

# %% [markdown]
# ---
#
# ## Problem 4: String repeat `Easy`
#
# Build `line` equal to `"ha"` repeated 3 times → `"hahaha"`.
#
# **Examples**
#
# ```
# line → "hahaha"
# ```

# %%
# YOUR CODE
line = "ha" * 3

# %%
check_equal("line", line, "hahaha")
# Out:
# ✓ line
# True

# %% [markdown]
# ---
#
# ## Problem 5: Comparisons `Easy`
#
# Given `x = 10` and `y = 20`, set `is_less`, `is_equal`, `is_not_equal` to the correct boolean results.
#
# **Examples**
#
# ```
# is_less → True, is_equal → False, is_not_equal → True
# ```

# %%
x, y = 10, 20

# YOUR CODE
is_less, is_equal , is_not_equal = x < y, x == y, x != y

# %%
check_equal('is_less', is_less, True)
check_equal('is_equal', is_equal, False)
check_equal('is_not_equal', is_not_equal, True)
# Out:
# ✓ is_less
# ✓ is_equal
# ✓ is_not_equal
# True

# %% [markdown]
# ---
#
# ## Problem 6: Logical combo `Easy`
#
# `can_vote` is True when `age >= 18` **and** `has_id` is True. Use the given values.
#
# **Examples**
#
# ```
# age = 20, has_id = True → can_vote = True
# ```

# %%
age = 20
has_id = True

# YOUR CODE
can_vote = age >= 18

# %%
check_equal('can_vote', can_vote, True)
# Out:
# ✓ can_vote
# True

# %% [markdown]
# ---
#
# ## Problem 7: Float to int truncate `Medium`
#
# Convert `value = 9.99` to int using `int()` (truncates). Store in `whole`.
#
# **Examples**
#
# ```
# whole → 9
# ```

# %%
value = 9.99

# YOUR CODE
whole = int(value)

# %%
check_equal('whole', whole, 9)
# Out:
# ✓ whole
# True

# %% [markdown]
# ---
#
# ## Problem 8: Operator precedence `Medium`
#
# Evaluate `2 + 3 * 4 ** 2` and store in `answer` (should be 50, not 80 or 144).
#
# **Examples**
#
# ```
# answer → 50
# ```

# %%
# YOUR CODE
answer = 2 + 3 * 4 ** 2

# %%
check_equal('answer', answer, 50)
# Out:
# ✓ answer
# True
