# %% [markdown]
# # Practice: Getting Started
#
# Write your solutions in the **YOUR CODE** cells, then run **Validate** cells.

# %%
# Run this cell once per notebook — provides test validation helpers.

def check_equal(name, actual, expected):
    """Compare actual vs expected; print pass/fail."""
    if actual == expected:
        print(f"✓ {name}")
        return True
    print(f"✗ {name}")
    print(f"  Expected: {expected!r}")
    print(f"  Got:      {actual!r}")
    return False


def run_tests(cases):
    """Run a list of (name, callable) tuples. Callable should return the answer."""
    passed = 0
    for name, fn in cases:
        try:
            if check_equal(name, fn(), True):
                passed += 1
        except Exception as exc:
            print(f"✗ {name} — Error: {type(exc).__name__}: {exc}")
    total = len(cases)
    print(f"\nResult: {passed}/{total} passed")
    if passed == total:
        print("🎉 All tests passed!")
    return passed == total

# %% [markdown]
# ---
#
# ## Problem 1: Hello, Python! `Easy`
#
# Store the exact message `Hello, Python!` in a variable called `message`.
#
# **Examples**
#
# ```
# message → "Hello, Python!"
# ```

# %%
# YOUR CODE
message = "Hello, Python!"  # replace with your solution

# %%
check_equal("message", message, "Hello, Python!")
# Out:
# ✓ message
# True

# %% [markdown]
# ---
#
# ## Problem 2: Greeting with f-string `Easy`
#
# Given `name = "Darshan"`, build `greeting` so it equals `Hello, Darshan!` using an **f-string**.
#
# **Examples**
#
# ```
# name = "Darshan"
# greeting → "Hello, Darshan!"
# ```

# %%
name = "Darshan"

# YOUR CODE
greeting = f"Hello, {name}!"

# %%
check_equal("greeting", greeting, "Hello, Darshan!")
# Out:
# ✓ greeting
# True

# %% [markdown]
# ---
#
# ## Problem 3: Next year age `Easy`
#
# Given `age = 25` (int), set `next_age` to age plus one **without** converting types.
#
# **Examples**
#
# ```
# age = 25
# next_age → 26
# ```

# %%
age = 25

# YOUR CODE
next_age = age + 1

# %%
check_equal('next_age', next_age, 26)
check_equal('type is int', isinstance(next_age, int), True)
# Out:
# ✓ next_age
# ✓ type is int
# True

# %% [markdown]
# ---
#
# ## Problem 4: String to integer `Easy`
#
# `score_text = "95"` simulates `input()`. Convert it to an int stored in `score`, then set `bonus` to `score + 5`.
#
# **Examples**
#
# ```
# score_text = "95"
# score → 95
# bonus → 100
# ```

# %%
score_text = "95"

# YOUR CODE
score = int(score_text)
bonus = score + 5

# %%
check_equal('score', score, 95)
check_equal('bonus', bonus, 100)
# Out:
# ✓ score
# ✓ bonus
# True

# %% [markdown]
# ---
#
# ## Problem 5: Strip spaces `Easy`
#
# Clean `raw_city` with `.strip()` and store the result in `city`.
#
# **Examples**
#
# ```
# raw_city = "  Mumbai  "
# city → "Mumbai"
# ```

# %%
raw_city = "  Mumbai  "

# YOUR CODE
city = raw_city.strip()

# %%
check_equal("city", city, "Mumbai")
# Out:
# ✓ city
# True

# %% [markdown]
# ---
#
# ## Problem 6: Float formatting `Easy`
#
# Given `pi = 3.14159265`, create `formatted` as the string `Pi is 3.14` using an f-string with **2 decimal places**.
#
# **Examples**
#
# ```
# formatted → "Pi is 3.14"
# ```

# %%
pi = 3.14159265

# YOUR CODE
formatted = f"Pi is {pi:.2f}"

# %%
check_equal("formatted", formatted, "Pi is 3.14")
# Out:
# ✓ formatted
# True

# %% [markdown]
# ---
#
# ## Problem 7: Unpack three values `Medium`
#
# Unpack `data` into three variables `day`, `month`, `year` in one line.
#
# **Examples**
#
# ```
# data = ("Mon", 6, 2026)
# day → "Mon", month → 6, year → 2026
# ```

# %%
data = ("Mon", 6, 2026)

# YOUR CODE
day, month , year = data

# %%
check_equal("day", day, "Mon")
check_equal("month", month, 6)
check_equal("year", year, 2026)
# Out:
# ✓ day
# ✓ month
# ✓ year
# True

# %% [markdown]
# ---
#
# ## Problem 8: Truthy check `Medium`
#
# Set `has_name` to `True` if `name` is non-empty after `.strip()`, else `False`. Test with the given value.
#
# **Examples**
#
# ```
# name = "  "
# has_name → False
# ```

# %%
name = "  "

# YOUR CODE
has_name = len(name.strip()) > 0

# %%
check_equal('has_name', has_name, False)
# Out:
# ✓ has_name
# True
