# %% [markdown]
# # Practice: Strings
#
# Write your solutions in the **YOUR CODE** cells, then run **Validate** cells.

# %%
# Run this cell once per notebook — provides test validation helpers.

def check_equal(name, actual, expected):
    """Compare actual vs expected; print pass/fail."""
    if actual == expected:
        print(f"✓ {name}")
        return True
    print(f"✗ {name}")
    print(f"  Expected: {expected!r}")
    print(f"  Got:      {actual!r}")
    return False


def run_tests(cases):
    """Run a list of (name, callable) tuples. Callable should return the answer."""
    passed = 0
    for name, fn in cases:
        try:
            if check_equal(name, fn(), True):
                passed += 1
        except Exception as exc:
            print(f"✗ {name} — Error: {type(exc).__name__}: {exc}")
    total = len(cases)
    print(f"\nResult: {passed}/{total} passed")
    if passed == total:
        print("🎉 All tests passed!")
    return passed == total

# %% [markdown]
# ---
#
# ## Problem 1: Reverse a string `Easy`
#
# Reverse `text` using slicing and store in `reversed_text`.
#
# **Examples**
#
# ```
# text = "Python" → reversed_text = "nohtyP"
# ```

# %%
text = "Python"

# YOUR CODE
reversed_text = text[::-1]

# %%
check_equal("reversed_text", reversed_text, "nohtyP")
# Out:
# ✓ reversed_text
# True

# %% [markdown]
# ---
#
# ## Problem 2: Count vowels `Easy`
#
# Count vowels `aeiou` (lowercase) in `word`. Given `word = "education"`.
#
# **Examples**
#
# ```
# vowel_count → 5
# ```

# %%
word = "education"

# YOUR CODE
vowel_count = 0
for c in word:
    if(c in ['a','e','i','o','u']):
        vowel_count += 1

# %%
check_equal('vowel_count', vowel_count, 5)
# Out:
# ✓ vowel_count
# True

# %% [markdown]
# ---
#
# ## Problem 3: Title case word `Easy`
#
# Turn `name = "darshan"` into `"Darshan"` using string methods.
#
# **Examples**
#
# ```
# proper → "Darshan"
# ```

# %%
name = "darshan"

# YOUR CODE
proper = name.title()

# %%
check_equal("proper", proper, "Darshan")
# Out:
# ✓ proper
# True

# %% [markdown]
# ---
#
# ## Problem 4: Palindrome check `Medium`
#
# Set `is_palindrome` to True if `s` reads the same forwards and backwards. `s = "level"`.
#
# **Examples**
#
# ```
# is_palindrome → True
# ```

# %%
s = "level"

# YOUR CODE
is_palindrome = True if s[::-1] == s else False

# %%
check_equal('is_palindrome', is_palindrome, True)
# Out:
# ✓ is_palindrome
# True

# %% [markdown]
# ---
#
# ## Problem 5: Replace word `Easy`
#
# Replace `"bad"` with `"good"` in `sentence`.
#
# **Examples**
#
# ```
# "bad day" → "good day"
# ```

# %%
sentence = "bad day"

# YOUR CODE
fixed = sentence.replace("bad","good")

# %%
check_equal("fixed", fixed, "good day")
# Out:
# ✓ fixed
# True

# %% [markdown]
# ---
#
# ## Problem 6: Split and join `Medium`
#
# Split `csv` by commas, then join with `" | "` → `"a | b | c"`.
#
# **Examples**
#
# ```
# csv = "a,b,c"
# ```

# %%
csv = "a,b,c"

# YOUR CODE
joined = " | ".join(csv.split(","))

# %%
check_equal("joined", joined, "a | b | c")
# Out:
# ✓ joined
# True

# %% [markdown]
# ---
#
# ## Problem 7: First three chars `Easy`
#
# Slice the first 3 characters of `lang` into `short`.
#
# **Examples**
#
# ```
# lang = "Python" → short = "Pyt"
# ```

# %%
lang = "Python"

# YOUR CODE
short = lang[:3]

# %%
check_equal("short", short, "Pyt")
# Out:
# ✓ short
# True

# %% [markdown]
# ---
#
# ## Problem 8: Case-insensitive compare `Medium`
#
# Set `same` to True if `a` and `b` are equal ignoring case and outer spaces.
#
# **Examples**
#
# ```
# a = "  Hello ", b = "hello" → same = True
# ```

# %%
a = "  Hello "
b = "hello"

# YOUR CODE
same = a.strip(" ").casefold() == b.casefold()

# %%
check_equal('same', same, True)
# Out:
# ✓ same
# True
