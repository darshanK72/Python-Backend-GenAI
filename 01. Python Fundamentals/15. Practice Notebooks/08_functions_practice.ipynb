# %% [markdown]
# # Practice: Functions
#
# Write your solutions in the **YOUR CODE** cells, then run **Validate** cells.

# %%
# Run this cell once per notebook — provides test validation helpers.

def check_equal(name, actual, expected):
    """Compare actual vs expected; print pass/fail."""
    if actual == expected:
        print(f"✓ {name}")
        return True
    print(f"✗ {name}")
    print(f"  Expected: {expected!r}")
    print(f"  Got:      {actual!r}")
    return False


def run_tests(cases):
    """Run a list of (name, callable) tuples. Callable should return the answer."""
    passed = 0
    for name, fn in cases:
        try:
            if check_equal(name, fn(), True):
                passed += 1
        except Exception as exc:
            print(f"✗ {name} — Error: {type(exc).__name__}: {exc}")
    total = len(cases)
    print(f"\nResult: {passed}/{total} passed")
    if passed == total:
        print("🎉 All tests passed!")
    return passed == total

# %% [markdown]
# ---
#
# ## Problem 1: greet `Easy`
#
# Define `greet(name)` returning `f"Hello, {name}!"`.
#
# **Examples**
#
# ```
# greet("Ada") → "Hello, Ada!"
# ```

# %%
# YOUR CODE
def greet(name):
    return f"Hello, {name}!"

# %%
check_equal('greet("Ada")', greet("Ada"), "Hello, Ada!")
# Out:
# ✓ greet("Ada")
# True

# %% [markdown]
# ---
#
# ## Problem 2: is_even `Easy`
#
# Define `is_even(n)` returning True if n is divisible by 2.
#
# **Examples**
#
# ```
# is_even(4) → True, is_even(7) → False
# ```

# %%
# YOUR CODE
def is_even(n):
    return n % 2 == 0

# %%
check_equal('is_even(4)', is_even(4), True)
check_equal('is_even(7)', is_even(7), False)
# Out:
# ✓ is_even(4)
# ✓ is_even(7)
# True

# %% [markdown]
# ---
#
# ## Problem 3: rectangle_area `Easy`
#
# Define `rectangle_area(w, h)` returning width × height.
#
# **Examples**
#
# ```
# rectangle_area(3, 4) → 12
# ```

# %%
# YOUR CODE
def rectangle_area(w, h):
    return w * h

# %%
check_equal('area', rectangle_area(3, 4), 12)
# Out:
# ✓ area
# True

# %% [markdown]
# ---
#
# ## Problem 4: max_of_three `Medium`
#
# Define `max_of_three(a, b, c)` without using built-in `max()`.
#
# **Examples**
#
# ```
# max_of_three(1, 9, 3) → 9
# ```

# %%
# YOUR CODE
def max_of_three(a, b, c):
    return max(a,max(b,c))

# %%
check_equal('max', max_of_three(1, 9, 3), 9)
# Out:
# ✓ max
# True

# %% [markdown]
# ---
#
# ## Problem 5: sum_all (*args) `Medium`
#
# Define `sum_all(*args)` returning the sum of all numeric arguments.
#
# **Examples**
#
# ```
# sum_all(1, 2, 3) → 6
# ```

# %%
# YOUR CODE
def sum_all(*args):
    sum = 0
    for ele in args:
        sum += ele
    return sum

# %%
check_equal('sum_all', sum_all(1, 2, 3), 6)
check_equal('sum_all one', sum_all(10), 10)
# Out:
# ✓ sum_all
# ✓ sum_all one
# True

# %% [markdown]
# ---
#
# ## Problem 6: power with default `Medium`
#
# Define `power(base, exp=2)` — default exponent is 2.
#
# **Examples**
#
# ```
# power(5) → 25, power(2, 3) → 8
# ```

# %%
# YOUR CODE
def power(base, exp=2):
    return base ** exp

# %%
check_equal('power(5)', power(5), 25)
check_equal('power(2,3)', power(2, 3), 8)
# Out:
# ✓ power(5)
# ✓ power(2,3)
# True

# %% [markdown]
# ---
#
# ## Problem 7: min_max `Medium`
#
# Define `min_max(nums)` returning a tuple `(smallest, largest)`.
#
# **Examples**
#
# ```
# min_max([3, 1, 4]) → (1, 4)
# ```

# %%
# YOUR CODE
def min_max(nums):
    return (min(nums),max(nums))

# %%
check_equal('min_max', min_max([3, 1, 4]), (1, 4))
# Out:
# ✓ min_max
# True

# %% [markdown]
# ---
#
# ## Problem 8: factorial `Medium`
#
# Define `factorial(n)` for n >= 0 using a loop.
#
# **Examples**
#
# ```
# factorial(5) → 120, factorial(0) → 1
# ```

# %%
# YOUR CODE
def factorial(n):
    f = 1
    for i in range(1,n+1):
        f *= i
    return f

# %%
check_equal('factorial(5)', factorial(5), 120)
check_equal('factorial(0)', factorial(0), 1)
# Out:
# ✓ factorial(5)
# ✓ factorial(0)
# True

# %% [markdown]
# ---
#
# ## Problem 9: count_vowels function `Medium`
#
# Define `count_vowels(text)` returning vowel count (aeiou, case-insensitive).
#
# **Examples**
#
# ```
# count_vowels("Hello") → 2
# ```

# %%
# YOUR CODE
def count_vowels(text):
    count = 0
    for c in text.lower():
        if c in ['a','e','i','o','u']:
            count += 1
    return count

# %%
check_equal("count_vowels", count_vowels("Hello"), 2)
# Out:
# ✓ count_vowels
# True

# %% [markdown]
# ---
#
# ## Problem 10: apply_twice `Hard`
#
# Define `apply_twice(f, x)` that returns `f(f(x))`.
#
# **Examples**
#
# ```
# apply_twice(lambda n: n + 1, 3) → 5
# ```

# %%
# YOUR CODE
def apply_twice(f, x):
    return f(f(x))

# %%
check_equal('apply_twice', apply_twice(lambda n: n + 1, 3), 5)
# Out:
# ✓ apply_twice
# True
