# %% [markdown]
# # Practice: Tuples & Sets
#
# Write your solutions in the **YOUR CODE** cells, then run **Validate** cells.

# %%
# Run this cell once per notebook — provides test validation helpers.

def check_equal(name, actual, expected):
    """Compare actual vs expected; print pass/fail."""
    if actual == expected:
        print(f"✓ {name}")
        return True
    print(f"✗ {name}")
    print(f"  Expected: {expected!r}")
    print(f"  Got:      {actual!r}")
    return False


def run_tests(cases):
    """Run a list of (name, callable) tuples. Callable should return the answer."""
    passed = 0
    for name, fn in cases:
        try:
            if check_equal(name, fn(), True):
                passed += 1
        except Exception as exc:
            print(f"✗ {name} — Error: {type(exc).__name__}: {exc}")
    total = len(cases)
    print(f"\nResult: {passed}/{total} passed")
    if passed == total:
        print("🎉 All tests passed!")
    return passed == total

# %% [markdown]
# ---
#
# ## Problem 1: Swap with tuple unpacking `Easy`
#
# Swap `x` and `y` in one line using tuple unpacking.
#
# **Examples**
#
# ```
# x=1, y=2 → x=2, y=1
# ```

# %%
x, y = 1, 2

# YOUR CODE
# swap x and y here

y,x = (x,y)

# %%
check_equal('x', x, 2)
check_equal('y', y, 1)
# Out:
# ✓ x
# ✓ y
# True

# %% [markdown]
# ---
#
# ## Problem 2: Tuple from range `Easy`
#
# Create `t` as a tuple of numbers 0 through 4 using `range` and `tuple()`.
#
# **Examples**
#
# ```
# t → (0, 1, 2, 3, 4)
# ```

# %%
# YOUR CODE
t = tuple(range(0,5))

# %%
check_equal('t', t, (0, 1, 2, 3, 4))
# Out:
# ✓ t
# True

# %% [markdown]
# ---
#
# ## Problem 3: Set union `Easy`
#
# Compute union of `a` and `b` into `all_tags` (unique, unordered). Compare as sets.
#
# **Examples**
#
# ```
# a = {"py", "code"}, b = {"code", "ai"} → 3 unique tags
# ```

# %%
a = {"py", "code"}
b = {"code", "ai"}

# YOUR CODE
all_tags = a.union(b)

# %%
check_equal("all_tags", all_tags, {"py", "code", "ai"})
# Out:
# ✓ all_tags
# True

# %% [markdown]
# ---
#
# ## Problem 4: Set intersection `Easy`
#
# Find elements in both `a` and `b`, store as `common`.
#
# **Examples**
#
# ```
# a = {1, 2, 3}, b = {3, 4} → {3}
# ```

# %%
a, b = {1, 2, 3}, {3, 4}

# YOUR CODE
common = a.intersection(b)

# %%
check_equal('common', common, {3})
# Out:
# ✓ common
# True

# %% [markdown]
# ---
#
# ## Problem 5: Unique letters `Medium`
#
# Build `letters` as a set of unique lowercase letters in `word`.
#
# **Examples**
#
# ```
# word = "hello" → {"h", "e", "l", "o"}
# ```

# %%
word = "hello"

# YOUR CODE
letters = set(word)

# %%
check_equal("letters", letters, {"h", "e", "l", "o"})
# Out:
# ✓ letters
# True

# %% [markdown]
# ---
#
# ## Problem 6: Remove duplicates with set `Medium`
#
# Use a set to count distinct values in `nums`, store count in `distinct_count`.
#
# **Examples**
#
# ```
# [1, 2, 2, 3, 3, 3] → distinct_count = 3
# ```

# %%
nums = [1, 2, 2, 3, 3, 3]

# YOUR CODE
distinct_count = len(set(nums))

# %%
check_equal('distinct_count', distinct_count, 3)
# Out:
# ✓ distinct_count
# True
