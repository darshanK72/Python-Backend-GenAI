# %% [markdown]
# # Datasets and Fine-Tuning Hooks
#
# Entry point for **dataset loading, formatting, and Hugging Face hooks** used before training open-weight models.
#
# **Full fine-tuning track:** **07. Fine-Tuning Open Models/** in this section (SFT, LoRA, QLoRA, TRL, evaluation, serving).
