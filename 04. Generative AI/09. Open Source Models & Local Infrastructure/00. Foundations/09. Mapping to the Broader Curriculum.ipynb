# %% [markdown]
# # Mapping to the Broader Curriculum
#
# | Topic | Where in this repo |
# |-------|-------------------|
# | Fine-tuning **concepts** | `02. GenAI & LLM Fundamentals/11` |
# | Fine-tuning **open models** (LoRA, QLoRA, TRL) | `09/07. Fine-Tuning Open Models` |
# | Fine-tuning **production & alignment** (RLHF, DPO, cloud) | `11/01/01. Production Fine-Tuning and Alignment` |
# | Cloud LLM APIs | `03. LLM API Integration` |
# | RAG | `06. Retrieval Augmented Generation (RAG)` |
# | Agents & MAS | `08. Multi Agent Systems (MAS)` |
