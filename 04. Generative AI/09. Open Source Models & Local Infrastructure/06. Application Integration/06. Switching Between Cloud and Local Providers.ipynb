# %% [markdown]
# # Switching Between Cloud and Local Providers
#
# Provider abstraction patterns — including routing to **fine-tuned local endpoints** served via Ollama or vLLM.
#
# **Related:** **07. Fine-Tuning Open Models → 12. Serving Fine-Tuned Models (Ollama, vLLM, GGUF)**
