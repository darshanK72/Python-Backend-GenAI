# %% [markdown]
# # GPTQ, AWQ, and BitsAndBytes
#
# Quantization formats for **inference** and as the foundation for **QLoRA training**.
#
# **Related:** **07. Fine-Tuning Open Models → 06. QLoRA - Quantized Fine-Tuning**
